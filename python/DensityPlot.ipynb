# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

mpl.rcParams['axes.unicode_minus'] = False

# %%
ser = pd.Series(np.random.randn(1000))

# %%
ser
# Out:
# 0     -0.766318
# 1      1.754796
# 2      0.935497
# 3      0.011408
# 4      0.676097
#          ...
# 995   -1.626718
# 996    1.383105
# 997   -0.091579
# 998    0.196371
# 999   -0.776208
# Length: 1000, dtype: float64

# %%
ser.plot.density()

# %%
ser.plot.kde()

# %%
ser.plot.kde()
#density plot은 연속적임
#이산적인 것을 곡선으로 만들어주네. 
#kde를 통해서 곡선으로 만들어 주는 것.

# %%
ser.plot.hist()

# %%
ser.plot.kde()
