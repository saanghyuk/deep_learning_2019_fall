# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mpl

# %matplotlib inline
mpl.rcParams['axes.unicode_minus'] = False

# %%
series = pd.Series(3 * np.random.rand(4),
                   index=['a', 'b', 'c', 'd'], name='series')

# %%
series
# Out:
# a    0.337420
# b    1.639196
# c    0.529909
# d    2.315422
# Name: series, dtype: float64

# %%
series.plot.pie(figsize=(6, 6))

# %%
df = pd.DataFrame({'mass': [0.330, 4.87, 5.97], 
                  'radius': [2439.7, 6051.8, 6378.1]}, 
                 index=['Mercury', 'Venus', 'Earth'])

# %%
df
# Out:
#          mass  radius
# Mercury  0.33  2439.7
# Venus    4.87  6051.8
# Earth    5.97  6378.1

# %%
plot=df.plot.pie(y='mass', figsize=(5,5))

# %%
plot=df.plot.pie(subplots=True, figsize=(10, 5))

# %%
series.plot.pie(labels=['AA', 'BB', 'CC', 'DD'], colors=['r', 'g', 'b', 'c'],
                autopct='%.2f', fontsize=20, figsize=(6, 6))
#autopct는 소숫점을 어디까지 표현을 할 건지

# %%
series = pd.Series([0.1]*4)

# %%
series
# Out:
# 0    0.1
# 1    0.1
# 2    0.1
# 3    0.1
# dtype: float64

# %%
series = pd.Series([0.1] * 4, index=['a', 'b', 'c', 'd'], name='series2')

# %%
series
# Out:
# a    0.1
# b    0.1
# c    0.1
# d    0.1
# Name: series2, dtype: float64

# %%
series.plot.pie(figsize=(6, 6))

# %% [markdown]
# Screen Shot 2019-10-03 at 1.55.02 AM![image.png](attachment:image.png)
