# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline
mpl.rcParams['axes.unicode_minus']=False

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])

# %%
df.head(5)
# Out:
#           a         b         c         d
# 0  0.602733  0.182979  0.077064  0.129968
# 1  0.086130  0.972218  0.946573  0.218377
# 2  0.872681  0.599218  0.845236  0.588558
# 3  0.349938  0.561565  0.412572  0.977367
# 4  0.670201  0.790870  0.269109  0.360494

# %%
df.plot.scatter(x='a', y='b')

# %%
df.plot.scatter(x='a', y='b', s=50)

# %%
df.plot.scatter(x='a', y='b', s=50, grid=True)

# %%
ax = df.plot.scatter(x='a', y='b', color='DarkRed', label='Group 1');
df.plot.scatter(x='c', y='d', color='DarkGreen', label='Group 2', ax=ax);

# %%
df.plot.scatter(x='a', y='b', c='c', s=50)

# %%
df.plot.scatter(x='a', y='b', s=df['c']*200);
