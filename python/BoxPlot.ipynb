# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.rand(10, 5), 
                  columns=['A', 'B', 'C', 'D', 'E'])

# %%
df
# Out:
#           A         B         C         D         E
# 0  0.478936  0.991004  0.464294  0.305543  0.417649
# 1  0.004798  0.657018  0.410042  0.638209  0.612539
# 2  0.583811  0.410238  0.822101  0.851644  0.262374
# 3  0.162526  0.931686  0.665847  0.537302  0.302182
# 4  0.458269  0.244020  0.822144  0.434262  0.871050
# 5  0.390306  0.337264  0.910256  0.476048  0.094090
# 6  0.085308  0.523474  0.269668  0.743075  0.214575
# 7  0.086146  0.060017  0.547863  0.799862  0.583122
# 8  0.764680  0.979776  0.173224  0.010180  0.878409
# 9  0.084325  0.554948  0.963438  0.481385  0.037419

# %%
df.describe()
# Out:
#                A          B          C          D          E
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.309911   0.568945   0.604888   0.527751   0.427341
# std     0.259294   0.321795   0.274792   0.251314   0.300045
# min     0.004798   0.060017   0.173224   0.010180   0.037419
# 25%     0.085518   0.355507   0.423605   0.444709   0.226525
# 50%     0.276416   0.539211   0.606855   0.509344   0.359916
# 75%     0.473769   0.863019   0.822133   0.716859   0.605185
# max     0.764680   0.991004   0.963438   0.851644   0.878409

# %%
df.plot.box()

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'DarkOrange',
         'medians': 'DarkBlue', 'caps': 'Gray'}

# %%
#r+는 이상치는 red로 +로 표시하라는 뜻. 
df.plot.box(color=color, sym='r+')

# %%
#
df.plot.box(vert=False, positions=[1, 4, 5, 6, 8])

# %%
df = pd.DataFrame(np.random.rand(10, 5))

# %%
df
# Out:
#           0         1         2         3         4
# 0  0.832521  0.379209  0.179270  0.840065  0.992005
# 1  0.954948  0.240923  0.631985  0.669614  0.447927
# 2  0.928267  0.789307  0.928284  0.082908  0.965420
# 3  0.095574  0.726528  0.413180  0.605141  0.215405
# 4  0.293908  0.479103  0.076068  0.933196  0.205489
# 5  0.599722  0.614491  0.692172  0.685190  0.296250
# 6  0.975204  0.922873  0.302936  0.968332  0.928061
# 7  0.656402  0.230659  0.313052  0.121436  0.145625
# 8  0.853913  0.066988  0.186963  0.558406  0.965399
# 9  0.993144  0.695913  0.041136  0.912588  0.115345

# %%
plt.figure();
bp = df.boxplot()

# %%
df = pd.DataFrame(np.random.rand(10, 2), columns=['Col1', 'Col2'])

# %%
df
# Out:
#        Col1      Col2
# 0  0.993441  0.043342
# 1  0.601276  0.312150
# 2  0.841164  0.687587
# 3  0.920641  0.786723
# 4  0.594403  0.259315
# 5  0.658974  0.973342
# 6  0.827380  0.261111
# 7  0.584793  0.476667
# 8  0.009457  0.301092
# 9  0.879159  0.688316

# %%
df['X'] = pd.Series(['A', 'A', 'A', 'A', 'A', 'B', 'B', 'B', 'B', 'B'])

# %%
df
# Out:
#        Col1      Col2  X
# 0  0.993441  0.043342  A
# 1  0.601276  0.312150  A
# 2  0.841164  0.687587  A
# 3  0.920641  0.786723  A
# 4  0.594403  0.259315  A
# 5  0.658974  0.973342  B
# 6  0.827380  0.261111  B
# 7  0.584793  0.476667  B
# 8  0.009457  0.301092  B
# 9  0.879159  0.688316  B

# %%
#by X로 구분하라는 것. 
plt.figure();
bp = df.boxplot(by='X')

# %%
np.random.seed(1234)

# %%
df_box = pd.DataFrame(np.random.randn(50, 2))

# %%
df_box['g'] = np.random.choice(['A', 'B'], size=50)

# %%
df_box.head()
# Out:
#           0         1  g
# 0  0.471435 -1.190976  A
# 1  1.432707 -0.312652  A
# 2 -0.720589  0.887163  B
# 3  0.859588 -0.636524  A
# 4  0.015696 -2.242685  B

# %%
df_box.loc[df_box['g'] == 'B', 1] += 3

# %%
# 행은 g컬럼이 B인 거 뽑아내고, 열은 1번째
df_box.loc[df_box['g']=='B', 1]
# Out:
# 2     0.887163
# 4    -2.242685
# 10   -0.655969
# 11    0.553439
# 12   -0.469305
# 13   -1.817027
# 14    1.058969
# 16    1.045938
# 17   -0.122092
# 18   -0.322795
# 19    2.390961
# 21   -2.074978
# 22   -0.897157
# 23    0.018289
# 24    0.215269
# 25   -1.445810
# 27   -0.144620
# 28   -0.035513
# 30   -0.070345
# 35    0.462060
# 36    0.523508
# 37    2.007843
# 38   -1.152659
# 39    0.039513
# 41    0.152631
# 45   -0.399965
# 46   -0.584718
# 47   -0.081947
# Name: 1, dtype: float64

# %%
df_box.head()
# Out:
#           0         1  g
# 0  0.471435 -1.190976  A
# 1  1.432707 -0.312652  A
# 2 -0.720589  3.887163  B
# 3  0.859588 -0.636524  A
# 4  0.015696  0.757315  B

# %%
bp = df_box.boxplot(by='g')
#or bf=df_box.groupby('g').boxplot()

# %% [markdown]
# ## Area Plot

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
df
# Out:
#           a         b         c         d
# 0  0.556895  0.084774  0.333002  0.728429
# 1  0.142435  0.552469  0.273043  0.974495
# 2  0.667787  0.255653  0.108311  0.776181
# 3  0.782478  0.761604  0.914403  0.658623
# 4  0.568368  0.201756  0.698296  0.952195
# 5  0.889963  0.993567  0.818704  0.545122
# 6  0.451254  0.890557  0.973265  0.593411
# 7  0.366074  0.323095  0.871423  0.215634
# 8  0.734945  0.365619  0.801603  0.782736
# 9  0.701355  0.622777  0.493683  0.840538

# %%
df.plot.area()
#NAN은 자동으로 채워줌.

# %%
df.plot()
#그냥 이렇게 그리면 기본 플롯

# %%
df.plot.area()
#stacked가 true인게 디폴트

# %%
df.plot.area(stacked=False)

# %%
df.plot(grid=True)

# %%
df.plot.area(stacked=False, grid=True)
