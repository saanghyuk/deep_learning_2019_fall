# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

# %matplotlib inline

mpl.rcParams['axes.unicode_minus'] = False

# %%
from pandas.plotting import scatter_matrix

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
                  columns=['a', 'b', 'c', 'd'])

# %%
df.head()
# Out:
#           a         b         c         d
# 0 -1.952257  0.618983  0.873649 -0.750782
# 1  0.485064 -0.317047  2.099273 -0.161445
# 2 -1.041251 -0.651677 -0.866462  2.259430
# 3 -0.697368 -2.122843  0.776000  0.319659
# 4 -1.578340 -1.246209  0.000301 -2.092514

# %%
#kde - 커널밀도함수(kernal Density Estimation)
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a196d4160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1984d588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1987bb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a198b6128>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a198e16d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1990fc88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1994b278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19977860>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a19977898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a199e53c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19a16978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19a4bf28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a19a85518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19ab8ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19af60b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19b25668>]],
#       dtype=object)
