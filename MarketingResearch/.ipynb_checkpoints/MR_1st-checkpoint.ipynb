# %% [markdown]
# **<h1>Description<h1>**
# The Excel file Credit Risk Data provides information about bank customers who had applied for loans. The data include the purpose of the loan, checking(Interest X) and savings account balances(Interest O), number of months as a customer of the bank, months employed, gender, marital status, age, housing status and number of years at current residence, job type, and credit-risk classification by the bank.(for Wk1-3)<br>
#
# **a**. Compute the combined checking and savings account balance for each record in the database. Then sort the records by the number of months as a customer of the bank. From examining the data, does it appear that customers with a longer association with the bank have more assets? Construct a scatter chart to validate your conclusions.<br>
# **b**. More to come!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from pandas.plotting import scatter_matrix
import seaborn as sns
sns.set(style="ticks", color_codes=True)

# %matplotlib inline



mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_excel('Data_Sets.xlsx')

# %%
df1 = df

# %%
col_list=list(df1.columns.values)

# %%
col_list
# Out:
# ['Unnamed: 0',
#  'Credit Risk Data',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15']

# %%
col_list[13]
# Out:
# 'Unnamed: 13'

# %%
df1.drop([col_list[13], col_list[14], col_list[15]], inplace=True, axis=1)

# %%
df1 = df1.shift(-1)

# %%
df1
# Out:
#        Unnamed: 0 Credit Risk Data Unnamed: 2 Unnamed: 3       Unnamed: 4  \
# 0    Entry Number     Loan Purpose  Checking     Savings  Months Customer
# 1               1  Small Appliance          0        739               13
# 2               2        Furniture          0       1230               25
# 3               3          New Car          0        389               19
# 4               4        Furniture        638        347               13
# ..            ...              ...        ...        ...              ...
# 422           422        Furniture          0          0               31
# 423           423          New Car          0          0               25
# 424           424          New Car          0        712               16
# 425           425          New Car          0        912                7
# 426           NaN              NaN        NaN        NaN              NaN
#
#           Unnamed: 5 Unnamed: 6      Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0    Months Employed     Gender  Marital Status        Age    Housing
# 1                 12          M          Single         23        Own
# 2                  0          M        Divorced         32        Own
# 3                119          M          Single         38        Own
# 4                 14          M          Single         36        Own
# ..               ...        ...             ...        ...        ...
# 422               53          M          Single         30        Own
# 423              103          F        Divorced         28        Own
# 424                6          F        Divorced         28        Own
# 425               39          M          Single         44        Own
# 426              NaN        NaN             NaN        NaN        NaN
#
#     Unnamed: 10 Unnamed: 11  Unnamed: 12
# 0         Years         Job  Credit Risk
# 1             3   Unskilled          Low
# 2             1     Skilled         High
# 3             4  Management         High
# 4             2   Unskilled         High
# ..          ...         ...          ...
# 422           4     Skilled         High
# 423           2     Skilled         High
# 424           2     Skilled         High
# 425           3  Management          Low
# 426         NaN         NaN          NaN
#
# [427 rows x 13 columns]

# %%
new_col_names = pd.Series(df1.iloc[0])

# %%
new_col_names
# Out:
# Unnamed: 0             Entry Number
# Credit Risk Data       Loan Purpose
# Unnamed: 2                Checking
# Unnamed: 3                  Savings
# Unnamed: 4          Months Customer
# Unnamed: 5          Months Employed
# Unnamed: 6                   Gender
# Unnamed: 7           Marital Status
# Unnamed: 8                      Age
# Unnamed: 9                  Housing
# Unnamed: 10                   Years
# Unnamed: 11                     Job
# Unnamed: 12             Credit Risk
# Name: 0, dtype: object

# %%
df1.columns = list(new_col_names)

# %%
df1.columns
# Out:
# Index(['Entry Number', 'Loan Purpose', 'Checking ', 'Savings',
#        'Months Customer', 'Months Employed', 'Gender', 'Marital Status', 'Age',
#        'Housing', 'Years', 'Job', 'Credit Risk'],
#       dtype='object')

# %%
df1
# Out:
#      Entry Number     Loan Purpose  Checking   Savings  Months Customer  \
# 0    Entry Number     Loan Purpose  Checking   Savings  Months Customer
# 1               1  Small Appliance          0      739               13
# 2               2        Furniture          0     1230               25
# 3               3          New Car          0      389               19
# 4               4        Furniture        638      347               13
# ..            ...              ...        ...      ...              ...
# 422           422        Furniture          0        0               31
# 423           423          New Car          0        0               25
# 424           424          New Car          0      712               16
# 425           425          New Car          0      912                7
# 426           NaN              NaN        NaN      NaN              NaN
#
#      Months Employed  Gender  Marital Status  Age  Housing  Years         Job  \
# 0    Months Employed  Gender  Marital Status  Age  Housing  Years         Job
# 1                 12       M          Single   23      Own      3   Unskilled
# 2                  0       M        Divorced   32      Own      1     Skilled
# 3                119       M          Single   38      Own      4  Management
# 4                 14       M          Single   36      Own      2   Unskilled
# ..               ...     ...             ...  ...      ...    ...         ...
# 422               53       M          Single   30      Own      4     Skilled
# 423              103       F        Divorced   28      Own      2     Skilled
# 424                6       F        Divorced   28      Own      2     Skilled
# 425               39       M          Single   44      Own      3  Management
# 426              NaN     NaN             NaN  NaN      NaN    NaN         NaN
#
#      Credit Risk
# 0    Credit Risk
# 1            Low
# 2           High
# 3           High
# 4           High
# ..           ...
# 422         High
# 423         High
# 424         High
# 425          Low
# 426          NaN
#
# [427 rows x 13 columns]

# %%
df1=df1.drop(df1.index[0])

# %%
df1=df1.drop(df1.index[425])

# %%
df1
# Out:
#     Entry Number     Loan Purpose Checking  Savings Months Customer  \
# 1              1  Small Appliance         0     739              13
# 2              2        Furniture         0    1230              25
# 3              3          New Car         0     389              19
# 4              4        Furniture       638     347              13
# 5              5        Education       963    4754              40
# ..           ...              ...       ...     ...             ...
# 421          421  Small Appliance       497       0               7
# 422          422        Furniture         0       0              31
# 423          423          New Car         0       0              25
# 424          424          New Car         0     712              16
# 425          425          New Car         0     912               7
#
#     Months Employed Gender Marital Status Age Housing Years         Job  \
# 1                12      M         Single  23     Own     3   Unskilled
# 2                 0      M       Divorced  32     Own     1     Skilled
# 3               119      M         Single  38     Own     4  Management
# 4                14      M         Single  36     Own     2   Unskilled
# 5                45      M         Single  31    Rent     3     Skilled
# ..              ...    ...            ...  ..     ...   ...         ...
# 421              51      M         Single  35   Other     4     Skilled
# 422              53      M         Single  30     Own     4     Skilled
# 423             103      F       Divorced  28     Own     2     Skilled
# 424               6      F       Divorced  28     Own     2     Skilled
# 425              39      M         Single  44     Own     3  Management
#
#     Credit Risk
# 1           Low
# 2          High
# 3          High
# 4          High
# 5           Low
# ..          ...
# 421         Low
# 422        High
# 423        High
# 424        High
# 425         Low
#
# [425 rows x 13 columns]

# %%
df1.isnull()
# Out:
#      Entry Number  Loan Purpose  Checking   Savings  Months Customer  \
# 1           False         False      False    False            False
# 2           False         False      False    False            False
# 3           False         False      False    False            False
# 4           False         False      False    False            False
# 5           False         False      False    False            False
# ..            ...           ...        ...      ...              ...
# 421         False         False      False    False            False
# 422         False         False      False    False            False
# 423         False         False      False    False            False
# 424         False         False      False    False            False
# 425         False         False      False    False            False
#
#      Months Employed  Gender  Marital Status    Age  Housing  Years    Job  \
# 1              False   False           False  False    False  False  False
# 2              False   False           False  False    False  False  False
# 3              False   False           False  False    False  False  False
# 4              False   False           False  False    False  False  False
# 5              False   False           False  False    False  False  False
# ..               ...     ...             ...    ...      ...    ...    ...
# 421            False   False           False  False    False  False  False
# 422            False   False           False  False    False  False  False
# 423            False   False           False  False    False  False  False
# 424            False   False           False  False    False  False  False
# 425            False   False           False  False    False  False  False
#
#      Credit Risk
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# ..           ...
# 421        False
# 422        False
# 423        False
# 424        False
# 425        False
#
# [425 rows x 13 columns]

# %%
df1.isnull().sum()
# Out:
# Entry Number       0
# Loan Purpose       0
# Checking           0
# Savings            0
# Months Customer    0
# Months Employed    0
# Gender             0
# Marital Status     0
# Age                0
# Housing            0
# Years              0
# Job                0
# Credit Risk        0
# dtype: int64

# %% [markdown]
# There's no NaN value? Thank you very much!

# %%
del df1['Entry Number']

# %%
df1
# Out:
#         Loan Purpose Checking  Savings Months Customer Months Employed Gender  \
# 1    Small Appliance         0     739              13              12      M
# 2          Furniture         0    1230              25               0      M
# 3            New Car         0     389              19             119      M
# 4          Furniture       638     347              13              14      M
# 5          Education       963    4754              40              45      M
# ..               ...       ...     ...             ...             ...    ...
# 421  Small Appliance       497       0               7              51      M
# 422        Furniture         0       0              31              53      M
# 423          New Car         0       0              25             103      F
# 424          New Car         0     712              16               6      F
# 425          New Car         0     912               7              39      M
#
#     Marital Status Age Housing Years         Job Credit Risk
# 1           Single  23     Own     3   Unskilled         Low
# 2         Divorced  32     Own     1     Skilled        High
# 3           Single  38     Own     4  Management        High
# 4           Single  36     Own     2   Unskilled        High
# 5           Single  31    Rent     3     Skilled         Low
# ..             ...  ..     ...   ...         ...         ...
# 421         Single  35   Other     4     Skilled         Low
# 422         Single  30     Own     4     Skilled        High
# 423       Divorced  28     Own     2     Skilled        High
# 424       Divorced  28     Own     2     Skilled        High
# 425         Single  44     Own     3  Management         Low
#
# [425 rows x 12 columns]

# %% [markdown]
# ### We're ready to explore the Data.

# %% [markdown]
# I will visualize the Data first.

# %%
df1
# Out:
#         Loan Purpose Checking  Savings Months Customer Months Employed Gender  \
# 1    Small Appliance         0     739              13              12      M
# 2          Furniture         0    1230              25               0      M
# 3            New Car         0     389              19             119      M
# 4          Furniture       638     347              13              14      M
# 5          Education       963    4754              40              45      M
# ..               ...       ...     ...             ...             ...    ...
# 421  Small Appliance       497       0               7              51      M
# 422        Furniture         0       0              31              53      M
# 423          New Car         0       0              25             103      F
# 424          New Car         0     712              16               6      F
# 425          New Car         0     912               7              39      M
#
#     Marital Status Age Housing Years         Job Credit Risk
# 1           Single  23     Own     3   Unskilled         Low
# 2         Divorced  32     Own     1     Skilled        High
# 3           Single  38     Own     4  Management        High
# 4           Single  36     Own     2   Unskilled        High
# 5           Single  31    Rent     3     Skilled         Low
# ..             ...  ..     ...   ...         ...         ...
# 421         Single  35   Other     4     Skilled         Low
# 422         Single  30     Own     4     Skilled        High
# 423       Divorced  28     Own     2     Skilled        High
# 424       Divorced  28     Own     2     Skilled        High
# 425         Single  44     Own     3  Management         Low
#
# [425 rows x 12 columns]

# %% [markdown]
# I want to devide Categorical Data & Numerical Data.

# %%
df1.describe()
# Out:
#            Loan Purpose  Checking   Savings  Months Customer  Months Employed  \
# count               425        425      425              425              425
# unique               10        168      322               30              102
# top     Small Appliance          0        0               13                0
# freq                105        251       62               76               25
#
#        Gender Marital Status  Age Housing  Years      Job Credit Risk
# count     425            425  425     425    425      425         425
# unique      2              3   50       3      4        4           2
# top         M         Single   22     Own      4  Skilled         Low
# freq      290            233   21     292    169      271         214

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 425 entries, 1 to 425
# Data columns (total 12 columns):
# Loan Purpose       425 non-null object
# Checking           425 non-null object
# Savings            425 non-null object
# Months Customer    425 non-null object
# Months Employed    425 non-null object
# Gender             425 non-null object
# Marital Status     425 non-null object
# Age                425 non-null object
# Housing            425 non-null object
# Years              425 non-null object
# Job                425 non-null object
# Credit Risk        425 non-null object
# dtypes: object(12)
# memory usage: 43.2+ KB

# %% [markdown]
# All type is defined as object type. I have to divide all columns manually.

# %%
df1.head(1)
# Out:
#       Loan Purpose Checking  Savings Months Customer Months Employed Gender  \
# 1  Small Appliance         0     739              13              12      M
#
#   Marital Status Age Housing Years        Job Credit Risk
# 1         Single  23     Own     3  Unskilled         Low

# %%
cate_list = ['Loan Purpose','Gender', 'Marital Status', 'Housing', 'Job', 'Credit Risk']
num_list = ['Checking ', 'Savings', 'Months Customer','Months Employed',
           'Age', 'Years' ]

# %%
df1.columns.values
# Out:
# array(['Loan Purpose', 'Checking ', 'Savings', 'Months Customer',
#        'Months Employed', 'Gender', 'Marital Status', 'Age', 'Housing',
#        'Years', 'Job', 'Credit Risk'], dtype=object)

# %%
cate_df = df1[cate_list]
print(cate_df.head(3))
# Out:
#       Loan Purpose Gender Marital Status Housing         Job Credit Risk
# 1  Small Appliance      M         Single     Own   Unskilled         Low
# 2        Furniture      M       Divorced     Own     Skilled        High
# 3          New Car      M         Single     Own  Management        High

# %%
num_df = df1[num_list]
print(num_df.head(3))
# Out:
#   Checking  Savings Months Customer Months Employed Age Years
# 1         0     739              13              12  23     3
# 2         0    1230              25               0  32     1
# 3         0     389              19             119  38     4

# %%
num_df = num_df.infer_objects()

#make type to int64

# %%
num_df.hist(bins=30, figsize=(8, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a2633c588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a29a99d30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a296de6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a269f7160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a280fd5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2a2dee48>]],
#       dtype=object)

# %%
num_df['Years'].plot.box( sym='r+')

# %%
scatter_matrix(num_df, alpha=0.2, figsize=(10, 10), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1c2a752978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2a778668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2a79dfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2a8609b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2a88d390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2a8b3d30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c2a8e0710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2a90f128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2a90f160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2a961470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2a988e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2a9b37f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c2a9e41d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2aa07b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2aa42550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2aa71ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2aaa88d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2aae52b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c2ab12c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2ab4b630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2ab7afd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2abb29b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2abef390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2ac1cd30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c2ac56710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2ac910f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2acbfa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2acfa470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2ad29e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2ad627f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c2ad9c1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2adc9b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2ae05550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2ae35ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2ae6d8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2aea92b0>]],
#       dtype=object)

# %%
cate_df
# Out:
#         Loan Purpose Gender Marital Status Housing         Job Credit Risk
# 1    Small Appliance      M         Single     Own   Unskilled         Low
# 2          Furniture      M       Divorced     Own     Skilled        High
# 3            New Car      M         Single     Own  Management        High
# 4          Furniture      M         Single     Own   Unskilled        High
# 5          Education      M         Single    Rent     Skilled         Low
# ..               ...    ...            ...     ...         ...         ...
# 421  Small Appliance      M         Single   Other     Skilled         Low
# 422        Furniture      M         Single     Own     Skilled        High
# 423          New Car      F       Divorced     Own     Skilled        High
# 424          New Car      F       Divorced     Own     Skilled        High
# 425          New Car      M         Single     Own  Management         Low
#
# [425 rows x 6 columns]

# %%
cate_df = cate_df.astype('category')

# %%
cate_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 425 entries, 1 to 425
# Data columns (total 6 columns):
# Loan Purpose      425 non-null category
# Gender            425 non-null category
# Marital Status    425 non-null category
# Housing           425 non-null category
# Job               425 non-null category
# Credit Risk       425 non-null category
# dtypes: category(6)
# memory usage: 6.8 KB

# %%
frames = [cate_df, num_df]

# %%
df2 = pd.concat(frames, axis=1, sort=False)

# %%
df2
# Out:
#         Loan Purpose Gender Marital Status Housing         Job Credit Risk  \
# 1    Small Appliance      M         Single     Own   Unskilled         Low
# 2          Furniture      M       Divorced     Own     Skilled        High
# 3            New Car      M         Single     Own  Management        High
# 4          Furniture      M         Single     Own   Unskilled        High
# 5          Education      M         Single    Rent     Skilled         Low
# ..               ...    ...            ...     ...         ...         ...
# 421  Small Appliance      M         Single   Other     Skilled         Low
# 422        Furniture      M         Single     Own     Skilled        High
# 423          New Car      F       Divorced     Own     Skilled        High
# 424          New Car      F       Divorced     Own     Skilled        High
# 425          New Car      M         Single     Own  Management         Low
#
#      Checking   Savings  Months Customer  Months Employed  Age  Years
# 1            0      739               13               12   23      3
# 2            0     1230               25                0   32      1
# 3            0      389               19              119   38      4
# 4          638      347               13               14   36      2
# 5          963     4754               40               45   31      3
# ..         ...      ...              ...              ...  ...    ...
# 421        497        0                7               51   35      4
# 422          0        0               31               53   30      4
# 423          0        0               25              103   28      2
# 424          0      712               16                6   28      2
# 425          0      912                7               39   44      3
#
# [425 rows x 12 columns]

# %%
df2['saving_total'] = df2['Checking ']+df2['Savings']

# %%
df2.dtypes
# Out:
# Loan Purpose       category
# Gender             category
# Marital Status     category
# Housing            category
# Job                category
# Credit Risk        category
# Checking              int64
# Savings               int64
# Months Customer       int64
# Months Employed       int64
# Age                   int64
# Years                 int64
# saving_total          int64
# dtype: object

# %%
for i in cate_list:
    sns.catplot(x=i, y="saving_total", jitter=False, data=df2);

# %%
sns.catplot(x="Job", y="saving_total", hue='Gender',jitter=False, data=df2);

# %%
sns.catplot(x="Housing", y="saving_total", hue='Gender',
            kind='swarm', data=df2);

# %% [markdown]
# Q1: a. Compute the combined checking and savings account balance for each record in the database. Then sort the records by the number of months as a customer of the bank. From examining the data, does it appear that customers with a longer association with the bank have more assets? Construct a scatter chart to validate your conclusions.

# %%
df2.plot.scatter(x='Months Customer', y='saving_total')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
df1.head()
# Out:
#       Loan Purpose Checking  Savings Months Customer Months Employed Gender  \
# 1  Small Appliance         0     739              13              12      M
# 2        Furniture         0    1230              25               0      M
# 3          New Car         0     389              19             119      M
# 4        Furniture       638     347              13              14      M
# 5        Education       963    4754              40              45      M
#
#   Marital Status Age Housing Years         Job Credit Risk
# 1         Single  23     Own     3   Unskilled         Low
# 2       Divorced  32     Own     1     Skilled        High
# 3         Single  38     Own     4  Management        High
# 4         Single  36     Own     2   Unskilled        High
# 5         Single  31    Rent     3     Skilled         Low

# %%
df2.head()
# Out:
#       Loan Purpose Gender Marital Status Housing         Job Credit Risk  \
# 1  Small Appliance      M         Single     Own   Unskilled         Low
# 2        Furniture      M       Divorced     Own     Skilled        High
# 3          New Car      M         Single     Own  Management        High
# 4        Furniture      M         Single     Own   Unskilled        High
# 5        Education      M         Single    Rent     Skilled         Low
#
#    Checking   Savings  Months Customer  Months Employed  Age  Years  \
# 1          0      739               13               12   23      3
# 2          0     1230               25                0   32      1
# 3          0      389               19              119   38      4
# 4        638      347               13               14   36      2
# 5        963     4754               40               45   31      3
#
#    saving_total
# 1           739
# 2          1230
# 3           389
# 4           985
# 5          5717

# %%
df2.describe()
# Out:
#           Checking        Savings  Months Customer  Months Employed  \
# count    425.000000    425.000000       425.000000       425.000000
# mean    1048.014118   1812.562353        22.896471        31.896471
# std     3147.183472   3597.285020        12.267599        32.259321
# min        0.000000      0.000000         5.000000         0.000000
# 25%        0.000000    228.000000        13.000000         6.000000
# 50%        0.000000    596.000000        19.000000        20.000000
# 75%      560.000000    921.000000        28.000000        47.000000
# max    19812.000000  19811.000000        73.000000       119.000000
#
#               Age       Years  saving_total
# count  425.000000  425.000000    425.000000
# mean    34.397647    2.840000   2860.576471
# std     11.045126    1.087146   4826.993904
# min     18.000000    1.000000      0.000000
# 25%     26.000000    2.000000    490.000000
# 50%     32.000000    3.000000    836.000000
# 75%     41.000000    4.000000   2632.000000
# max     73.000000    4.000000  32542.000000

# %%
cate_df.describe()
# Out:
#            Loan Purpose Gender Marital Status Housing      Job Credit Risk
# count               425    425            425     425      425         425
# unique               10      2              3       3        4           2
# top     Small Appliance      M         Single     Own  Skilled         Low
# freq                105    290            233     292      271         214

# %% [markdown]
# <h2>One population Mean Testing about Savings</h2>
#
# <br>
# sample mean = 2860.576471<br>
# sample std = 4826.993904
#
#
# H0 : μ=2800
# <br>
# H1 : μ≠2800

# %%
import statsmodels.api as sm
import numpy as np
import pandas as pd

# %%
savings_total = df2['saving_total']

# %%
print('The number of data : ',len(savings_total))
print('Sample Mean : ', savings_total.mean())
print('Sample Std : ', savings_total.std())
# Out:
# The number of data :  425
# Sample Mean :  2860.576470588235
# Sample Std :  4826.993904117601

# %%
#Let's set a = 0.05

# %%
sm.stats.ztest(savings_total, value=2800, alternative='two-sided')
# Out:
# (0.2587150425540816, 0.7958551123461524)

# %% [markdown]
# P-value pretty high here, and then we can't reject the H0

# %%
from scipy.stats import pearsonr

# %%
savings=df2['saving_total']

# %%
months_customer=df2['Months Customer']

# %%
ax1 = df2.plot.scatter(x='saving_total', y='Months Customer', c='DarkBlue')

# %%
corr, p = pearsonr(savings, months_customer)

# %%
print(corr, p)
# Out:
# -0.06121000781711819 0.2079070784127837

# %% [markdown]
# correlation coefficient = -0.06121000781711819 <br>
# p-value = 0.2079070784127837

# %% [markdown]
# In this pearsonr function, The null hypothesis is that the two variables are uncorrelated. The p-value is a number between zero and one that represents the probability that your data would have arisen if the null hypothesis were true.

# %% [markdown]
# corr is near 0, and P-value is really big. <br>
# So, we cannot reject the null hypothesis(Uncorrelated)

# %% [markdown]
# If 45 is all, 20개 Random Sampling
